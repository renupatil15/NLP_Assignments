# %%
import nltk
from nltk.corpus import wordnet as wn
from nltk.tokenize import word_tokenize
from nltk import pos_tag

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def get_wordnet_pos(treebank_tag):
    if treebank_tag.startswith('J'):
        return wn.ADJ
    elif treebank_tag.startswith('V'):
        return wn.VERB
    elif treebank_tag.startswith('N'):
        return wn.NOUN
    elif treebank_tag.startswith('R'):
        return wn.ADV
    else:
        return None

# %%
def extract_semantics(word, pos):
    synsets = wn.synsets(word, pos=pos)

    synonyms = set()
    antonyms = set()
    hypernyms = set()

    for syn in synsets:
        # Synonyms
        for lemma in syn.lemmas():
            synonyms.add(lemma.name())

            # Antonyms
            if lemma.antonyms():
                antonyms.add(lemma.antonyms()[0].name())

        # Hypernyms
        for hyper in syn.hypernyms():
            for lemma in hyper.lemmas():
                hypernyms.add(lemma.name())

    return synonyms, antonyms, hypernyms

# %%
def analyze_text(text):
    tokens = word_tokenize(text)
    tagged_words = pos_tag(tokens)

    print("\n SEMANTIC ANALYSIS USING WORDNET")
    print("=" * 60)

    for word, tag in tagged_words:
        wn_pos = get_wordnet_pos(tag)

        if wn_pos:
            synonyms, antonyms, hypernyms = extract_semantics(word, wn_pos)

            print(f"\nWord: {word}")
            print(f"POS Tag: {tag}")

            print("Synonyms:", ", ".join(list(synonyms)[:8]) if synonyms else "None")
            print("Antonyms:", ", ".join(list(antonyms)) if antonyms else "None")
            print("Hypernyms:", ", ".join(list(hypernyms)[:5]) if hypernyms else "None")

# %%
text = input("Enter a sentence or paragraph: ")
analyze_text(text)
# Out:
# Enter a sentence or paragraph: I am Renuka, a passionate and kind-hearted individual who deeply loves dogs and all animals, admires their loyalty and innocence, and strongly believes in treating every living being with care, compassion, and respect while continuously supporting animal welfare and coexistence with nature.
#
# 🔍 SEMANTIC ANALYSIS USING WORDNET
# ============================================================
#
# Word: am
# POS Tag: VBP
# Synonyms: equal, make_up, be, follow, cost, comprise, represent, embody
# Antonyms: differ
# Hypernyms: symbolize, be, typify, represent, stand_for
#
# Word: Renuka
# POS Tag: NNP
# Synonyms: None
# Antonyms: None
# Hypernyms: None
#
# Word: passionate
# POS Tag: NN
# Synonyms: None
# Antonyms: None
# Hypernyms: None
#
# Word: kind-hearted
# POS Tag: JJ
# Synonyms: kindhearted, kind-hearted
# Antonyms: None
# Hypernyms: None
#
# Word: individual
# POS Tag: NN
# Synonyms: someone, person, individual, mortal, soul, somebody
# Antonyms: None
# Hypernyms: causal_agency, cause, being, causal_agent, organism
#
# Word: deeply
# POS Tag: VBP
# Synonyms: None
# Antonyms: None
# Hypernyms: None
#
# Word: loves
# POS Tag: NNS
# Synonyms: dearest, sexual_love, love, honey, love_life, passion, dear, lovemaking
# Antonyms: hate
# Hypernyms: sexual_activity, sexual_practice, concupiscence, lover, score
#
# Word: dogs
# POS Tag: NNS
# Synonyms: heel, detent, cad, frankfurter, firedog, dog, hotdog, pawl
# Antonyms: None
# Hypernyms: stop, canine, gent, unpleasant_woman, fellow
#
# Word: animals
# POS Tag: NNS
# Synonyms: brute, beast, animate_being, fauna, creature, animal
# Antonyms: None
# Hypernyms: being, organism
#
# Word: admires
# POS Tag: VBZ
# Synonyms: admire, look_up_to
# Antonyms: look_down_on
# Hypernyms: look, esteem, prize, value, prise
#
# Word: loyalty
# POS Tag: NN
# Synonyms: allegiance, trueness, commitment, loyalty, dedication
# Antonyms: disloyalty
# Hypernyms: love, faithfulness, fidelity, cooperation
#
# Word: innocence
# POS Tag: NN
# Synonyms: innocence, ingenuousness, pureness, sinlessness, whiteness, naturalness, artlessness, purity
# Antonyms: guilt
# Hypernyms: condition, status, naiveness, naivete, naivety
#
# Word: strongly
# POS Tag: RB
# Synonyms: strongly, powerfully
# Antonyms: weakly
# Hypernyms: None
#
# Word: believes
# POS Tag: VBZ
# Synonyms: consider, conceive, believe, trust, think
# Antonyms: disbelieve
# Hypernyms: credit, believe, judge, expect, accept
#
# Word: treating
# POS Tag: VBG
# Synonyms: plow, address, process, handle, care_for, deal, cover, regale
# Antonyms: None
# Hypernyms: impact, cater, bear_upon, supply, affect
#
# Word: living
# POS Tag: NN
# Synonyms: life, livelihood, bread_and_butter, living, aliveness, animation, sustenance, keep
# Antonyms: dead
# Hypernyms: resource, being, people, experience, existence
#
# Word: being
# POS Tag: VBG
# Synonyms: equal, make_up, be, follow, cost, comprise, represent, embody
# Antonyms: differ
# Hypernyms: symbolize, be, typify, represent, stand_for
#
# Word: care
# POS Tag: NN
# Synonyms: tending, care, maintenance, caution, guardianship, upkeep, attention, aid
# Antonyms: None
# Hypernyms: protection, mend, judiciousness, plight, anxiety
#
# Word: compassion
# POS Tag: NN
# Synonyms: compassion, pity, compassionateness
# Antonyms: None
# Hypernyms: fellow_feeling, sympathy, mercifulness, mercy
#
# Word: respect
# POS Tag: NN
# Synonyms: esteem, obedience, deference, regard, respect, respectfulness
# Antonyms: disrespect, disesteem
# Hypernyms: affectionateness, fondness, philia, honor, warmness
#
# Word: continuously
# POS Tag: RB
# Synonyms: ceaselessly, continuously, unceasingly, incessantly, endlessly, unendingly
# Antonyms: None
# Hypernyms: None
#
# Word: supporting
# POS Tag: VBG
# Synonyms: hold, back_up, hold_up, corroborate, stomach, patronise, fend_for, back
# Antonyms: negate
# Hypernyms: hold, O.K., give, represent, check
#
# Word: animal
# POS Tag: JJ
# Synonyms: animal, fleshly, carnal, sensual
# Antonyms: None
# Hypernyms: None
#
# Word: welfare
# POS Tag: NN
# Synonyms: public_assistance, benefit, wellbeing, eudaimonia, well-being, social_welfare, upbeat, eudaemonia
# Antonyms: ill-being
# Hypernyms: financial_aid, good, prosperity, aid, successfulness
#
# Word: coexistence
# POS Tag: NN
# Synonyms: coexistence
# Antonyms: None
# Hypernyms: being, existence, beingness
#
# Word: nature
# POS Tag: NN
# Synonyms: nature
# Antonyms: None
# Hypernyms: creation, causal_agency, quality, macrocosm, cause
